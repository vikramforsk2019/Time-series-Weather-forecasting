# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.getcwd()
os.chdir('/content/drive/My Drive/FSDP2019_DEEP_LEARNING/forskfssdpcodechallengesday31/weather')

# %%
weather_data = pd.read_csv('Weather_data.csv')

# %%
weather_data.shape
# Out:
# (98913, 20)

# %%
weather_data.head(5)
# Out:
#      datetime_utc  _conds   _dewptm  ...   _wgustm   _windchillm   _wspdm
# 0  19961101-11:00   Smoke       9.0  ...       NaN           NaN      7.4
# 1  19961101-12:00   Smoke      10.0  ...       NaN           NaN      NaN
# 2  19961101-13:00   Smoke      11.0  ...       NaN           NaN      NaN
# 3  19961101-14:00   Smoke      10.0  ...       NaN           NaN      NaN
# 4  19961101-16:00   Smoke      11.0  ...       NaN           NaN      0.0
#
# [5 rows x 20 columns]

# %%
weather_data.describe()
# Out:
#             _dewptm          _fog  ...   _windchillm        _wspdm
# count  98294.000000  98913.000000  ...    573.000000  96560.000000
# mean      15.817130      0.067109  ...      5.708202      7.685854
# std        7.096917      0.250213  ...      1.205967     11.995965
# min      -24.000000      0.000000  ...      2.100000      0.000000
# 25%       10.000000      0.000000  ...      4.900000      0.000000
# 50%       15.000000      0.000000  ...      6.100000      7.400000
# 75%       22.000000      0.000000  ...      6.800000     11.100000
# max       75.000000      1.000000  ...      7.300000   1514.900000
#
# [8 rows x 17 columns]

# %%
labels=weather_data[' _tempm']

# %%
features=weather_data.loc[:, weather_data.columns != ' _tempm']

# %% [markdown]
# df.set_axis(df['Date'], inplace=True)
# df.drop(columns=['Open', 'High', 'Low', 'Volume'], inplace=True)

# %%
features
# Out:
#          datetime_utc          _conds  ...   _windchillm   _wspdm
# 0      19961101-11:00           Smoke  ...           NaN      7.4
# 1      19961101-12:00           Smoke  ...           NaN      NaN
# 2      19961101-13:00           Smoke  ...           NaN      NaN
# 3      19961101-14:00           Smoke  ...           NaN      NaN
# 4      19961101-16:00           Smoke  ...           NaN      0.0
# ...               ...             ...  ...           ...      ...
# 98908  20161130-12:30            Mist  ...           NaN      0.0
# 98909  20161130-13:00            Mist  ...           NaN      0.0
# 98910  20161130-15:00  Patches of Fog  ...           NaN      0.0
# 98911  20161130-18:00  Patches of Fog  ...           NaN      0.0
# 98912  20161130-21:00            Mist  ...           NaN      0.0
#
# [98913 rows x 19 columns]

# %% [markdown]
# weather_data.info()

# %%
features=features.dropna(axis=1,how='all')

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98913 entries, 0 to 98912
# Data columns (total 18 columns):
# datetime_utc    98913 non-null object
#  _conds         98845 non-null object
#  _dewptm        98294 non-null float64
#  _fog           98913 non-null int64
#  _hail          98913 non-null int64
#  _heatindexm    29111 non-null float64
#  _hum           98160 non-null float64
#  _pressurem     98682 non-null float64
#  _rain          98913 non-null int64
#  _snow          98913 non-null int64
#  _thunder       98913 non-null int64
#  _tornado       98913 non-null int64
#  _vism          94497 non-null float64
#  _wdird         84533 non-null float64
#  _wdire         84533 non-null object
#  _wgustm        1063 non-null float64
#  _windchillm    573 non-null float64
#  _wspdm         96560 non-null float64
# dtypes: float64(9), int64(6), object(3)
# memory usage: 13.6+ MB

# %%
features=features.dropna(thresh=50000,axis=1)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98913 entries, 0 to 98912
# Data columns (total 15 columns):
# datetime_utc    98913 non-null object
#  _conds         98845 non-null object
#  _dewptm        98294 non-null float64
#  _fog           98913 non-null int64
#  _hail          98913 non-null int64
#  _hum           98160 non-null float64
#  _pressurem     98682 non-null float64
#  _rain          98913 non-null int64
#  _snow          98913 non-null int64
#  _thunder       98913 non-null int64
#  _tornado       98913 non-null int64
#  _vism          94497 non-null float64
#  _wdird         84533 non-null float64
#  _wdire         84533 non-null object
#  _wspdm         96560 non-null float64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 11.3+ MB

# %%
 feature=features.fillna(features.mean())

# %%
feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98913 entries, 0 to 98912
# Data columns (total 15 columns):
# datetime_utc    98913 non-null object
#  _conds         98845 non-null object
#  _dewptm        98913 non-null float64
#  _fog           98913 non-null int64
#  _hail          98913 non-null int64
#  _hum           98913 non-null float64
#  _pressurem     98913 non-null float64
#  _rain          98913 non-null int64
#  _snow          98913 non-null int64
#  _thunder       98913 non-null int64
#  _tornado       98913 non-null int64
#  _vism          98913 non-null float64
#  _wdird         98913 non-null float64
#  _wdire         84533 non-null object
#  _wspdm         98913 non-null float64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 11.3+ MB

# %%
feature.drop(columns=[' _conds',' _wspdm'])
# Out:
#          datetime_utc   _dewptm   _fog  ...     _vism     _wdird   _wdire
# 0      19961101-11:00       9.0      0  ...  5.000000  280.00000     West
# 1      19961101-12:00      10.0      0  ...  2.419885    0.00000    North
# 2      19961101-13:00      11.0      0  ...  2.419885    0.00000    North
# 3      19961101-14:00      10.0      0  ...  2.000000    0.00000    North
# 4      19961101-16:00      11.0      0  ...  1.200000    0.00000    North
# ...               ...       ...    ...  ...       ...        ...      ...
# 98908  20161130-12:30      17.0      0  ...  1.500000    0.00000    North
# 98909  20161130-13:00      16.0      0  ...  1.200000    0.00000    North
# 98910  20161130-15:00      16.0      1  ...  1.000000  162.55098      NaN
# 98911  20161130-18:00      14.0      1  ...  1.000000  162.55098      NaN
# 98912  20161130-21:00      13.0      0  ...  1.000000  162.55098      NaN
#
# [98913 rows x 13 columns]
